# %% [markdown]
# ##  EDA on IMDB Data Anlaysis Dataset

# %% [markdown]
# The dataset that is going to be used is 'IMDB Data Analysis' from Kaggle. This Data consist of 1000 movies and tv shows. In this we have to analyse the data with the help of python libraries i.e..
#
# Numpy and Pandas for Mathematical and Statistical Functions
#
# Matplotlib and Seaborn for Data Visualization

# %% [markdown]
# ## Data Preparation

# %%
# Importing Libraries

import pandas as pd
# pandas is aliased as pd
import numpy as np
# numpy is aliased as np
import matplotlib.pyplot as plt
# pyplot is aliased as plt
import seaborn as sns
# seaborn is aliased as sns

import warnings
warnings.filterwarnings("ignore")

# %%
# Loading the Data
df = pd.read_csv("/content/imdb_top_1000.csv")

# Showing the First 5 rows
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
# Showing the last 5 rows
df.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# ...

# %%
# Showing Random 5 rows
df.sample(5)
# Out:
#                                            Poster_Link           Series_Title  \
# 547  https://m.media-amazon.com/images/M/MV5BMTA0Y2...                Charade
# 580  https://m.media-amazon.com/images/M/MV5BMTYxMj...  Manchester by the Sea
# 488  https://m.media-amazon.com/images/M/MV5BYmQ5Mz...             District 9
# 452  https://m.media-amazon.com/images/M/MV5BYWQ0MG...        Brief Encounter
# 353  https://m.media-amazon.com/images/M/MV5BMjE2Nj...  Nefes: Vatan Sagolsun
#
#     Released_Year Certificate  Runtime                     Genre  IMDB_Rating  \
# 547          1963           U  113 min  Comedy, Mystery, Romance          7.9
# 580          2016          UA  137 min                     Drama          7.8
# 488          2009           A  112 min  Action, Sci-Fi, Thriller          7.9
# 452          1945           U   86 min            Drama, Romance          8.0
# 353          2009         NaN  128 min   Action, Drama, Thriller          8.0
#
# ...

# %%
# Showing the columns of the dataset
df.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %% [markdown]
# ## Description of the columns
#
# Poster_Link - Link of the poster that imdb using
#
# Series_Title = Name of the movie
#
# Released_Year - Year at which that movie released
#
# Certificate - Certificate earned by that movie
#
# Runtime - Total runtime of the movie
#
# Genre - Genre of the movie
#
#
# IMDB_Rating - Rating of the movie at IMDB site
#
# Overview - mini story/ summary
#
# Meta_score - Score earned by the movie
#
# Director - Name of the Director
#
# Star1,Star2,Star3,Star4 - Name of the Stars
#
# No_of_votes - Total number of votes
#
# Gross - Money earned by that movie

# %%
df.shape
# no. of rows = 1000 and no. of columns = 16
# Out:
# (1000, 16)

# %% [markdown]
# # Data preprocessing

# %%
# checking duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
# checking no. of unique values
df.nunique().sum()
# Out:
# 9238

# %% [markdown]
# # Showing Unique values in the columns of the data.

# %%
# showing unique entries in the 'Certificate' column
df['Certificate'].unique()
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', nan, 'PG', 'G', 'Passed', 'TV-14',
#        '16', 'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'],
#       dtype=object)

# %%
# showing unique entries in the 'Released_Year' column
df['Released_Year'].unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943', 'PG'], dtype=object)

# %%
# showing unique entries in the 'IMDB_Rating' Column
df['IMDB_Rating'].unique()
# Out:
# array([9.3, 9.2, 9. , 8.9, 8.8, 8.7, 8.6, 8.5, 8.4, 8.3, 8.2, 8.1, 8. ,
#        7.9, 7.8, 7.7, 7.6])

# %%
# showing unique entries in the 'Genre' Column
df['Genre'].unique()
# Out:
# array(['Drama', 'Crime, Drama', 'Action, Crime, Drama',
#        'Action, Adventure, Drama', 'Biography, Drama, History',
#        'Action, Adventure, Sci-Fi', 'Drama, Romance', 'Western',
#        'Action, Sci-Fi', 'Biography, Crime, Drama',
#        'Action, Adventure, Fantasy', 'Comedy, Drama, Thriller',
#        'Adventure, Drama, Sci-Fi', 'Animation, Adventure, Family',
#        'Drama, War', 'Crime, Drama, Fantasy', 'Comedy, Drama, Romance',
#        'Crime, Drama, Mystery', 'Crime, Drama, Thriller',
#        'Action, Drama, Mystery', 'Drama, Family, Fantasy', 'Drama, Music',
#        'Biography, Comedy, Drama', 'Drama, Mystery, Sci-Fi',
#        'Biography, Drama, Music', 'Crime, Mystery, Thriller',
#        'Animation, Adventure, Drama', 'Animation, Drama, War',
#        'Adventure, Comedy, Sci-Fi', 'Horror, Mystery, Thriller',
#        'Drama, Romance, War', 'Comedy, Drama, Family',
#        'Animation, Drama, Fantasy', 'Action, Biography, Drama',
# ...

# %%
# showing unique entries in the 'Meta_score' column
df['Meta_score'].unique()
# Out:
# array([ 80., 100.,  84.,  90.,  96.,  94.,  74.,  66.,  92.,  82.,  87.,
#         73.,  83.,  nan,  79.,  91.,  61.,  59.,  65.,  85.,  98.,  89.,
#         88.,  57.,  67.,  62.,  77.,  64.,  75.,  97.,  99.,  78.,  68.,
#         81.,  95.,  76.,  69.,  55.,  70.,  58.,  86.,  71.,  63.,  93.,
#         72.,  60.,  47.,  49.,  50.,  33.,  54.,  56.,  51.,  53.,  48.,
#         44.,  45.,  40.,  52.,  28.,  36.,  46.,  30.,  41.])

# %%
# checking Data Types
df.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %% [markdown]
# By Looking at the DataFrame we know that:
#
# 1. There are 16 columns of properties with 1000 rows of data.
# 2. Column 'IMDB_Rating' and 'Meta_Score' are in the type of float.
# 3. Column 'No_of_Votes' are in the type of int.

# %% [markdown]
# # Feature Selection

# %% [markdown]
# Dropping some Unnecessary columns which has no role in the Analysis and Visualization of data.

# %%
# Dropping Unnecessary columns
df= df.drop(['Poster_Link','Overview'],axis=1)
df.head(2)
# Out:
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating  Meta_score              Director          Star1  \
# 0          9.3        80.0        Frank Darabont    Tim Robbins
# 1          9.2       100.0  Francis Ford Coppola  Marlon Brando
#
#             Star2       Star3           Star4  No_of_Votes        Gross
# 0  Morgan Freeman  Bob Gunton  William Sadler      2343110   28,341,469
# 1       Al Pacino  James Caan    Diane Keaton      1620367  134,966,411

# %% [markdown]
# ## Data Cleaning

# %%
# checking null values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Gross            169
# Meta_score       157
# Certificate      101
# Series_Title       0
# Released_Year      0
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# dtype: int64

# %% [markdown]
# I think that the missing data exists for the following reasons:
#
# 1. Gross: Older movie where this information wasn't tracked
# 2. Meta_score: Less popular movie that doesn't have an available score
# 3. Certificate: Movies were not certified may be by some reason.

# %% [markdown]
# 1. Released_Year Column

# %%
# Counting values of 'Released_Year' Column
df['Released_Year'].value_counts()
# Out:
# 2014    32
# 2004    31
# 2009    29
# 2013    28
# 2016    28
#         ..
# 1926     1
# 1936     1
# 1924     1
# 1921     1
# PG       1
# Name: Released_Year, Length: 100, dtype: int64

# %%
# finding row where Released_Year = PG
x = df['Released_Year'].loc[df['Released_Year']=='PG']
x
# Out:
# 966    PG
# Name: Released_Year, dtype: object

# %%
# Dropping the row where Released_Year = PG by its index value
df = df.drop(labels=966, axis=0)

# showing unique values
df['Released_Year'].unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943'], dtype=object)

# %%
# Conversion of data type from Object to int
df['Released_Year'] = df['Released_Year'].astype(int)

# Checking Data Type of Released_Year Column
print(df['Released_Year'].dtypes)
# Out:
# int64

# %% [markdown]
# 2. Runtime Column

# %%
df['Runtime'].unique()
# Out:
# array(['142 min', '175 min', '152 min', '202 min', '96 min', '201 min',
#        '154 min', '195 min', '148 min', '139 min', '178 min', '161 min',
#        '179 min', '136 min', '146 min', '124 min', '133 min', '160 min',
#        '132 min', '153 min', '169 min', '130 min', '125 min', '189 min',
#        '116 min', '127 min', '118 min', '121 min', '207 min', '122 min',
#        '106 min', '112 min', '151 min', '150 min', '155 min', '119 min',
#        '110 min', '88 min', '137 min', '89 min', '165 min', '109 min',
#        '102 min', '87 min', '126 min', '147 min', '117 min', '181 min',
#        '149 min', '105 min', '164 min', '170 min', '98 min', '101 min',
#        '113 min', '134 min', '229 min', '115 min', '143 min', '95 min',
#        '104 min', '123 min', '131 min', '108 min', '81 min', '99 min',
#        '114 min', '129 min', '228 min', '128 min', '103 min', '107 min',
#        '68 min', '138 min', '156 min', '167 min', '163 min', '186 min',
# ...

# %%
# "Runtime" has 'min' as uneccessary suffix, and it could be numeric only

# Checking how many values in 'Runtime' column is digits
df['Runtime'].str.isdigit().sum() 

# Result is zero, so it means all contain suffix
# Out:
# 0

# %%
# For removing Suffix I use str.split() method

# This Method in Python split a string into a list of strings after breaking the given string by the specified separator.
df['Runtime'] = df['Runtime'].str.split(' ').str.get(0).astype(int)  # I use str.get(0) to get 1st list in the string.

# %%
# Checking unique values after changing 'Runtime' Column Data.
df['Runtime'].unique()
# Out:
# array([142, 175, 152, 202,  96, 201, 154, 195, 148, 139, 178, 161, 179,
#        136, 146, 124, 133, 160, 132, 153, 169, 130, 125, 189, 116, 127,
#        118, 121, 207, 122, 106, 112, 151, 150, 155, 119, 110,  88, 137,
#         89, 165, 109, 102,  87, 126, 147, 117, 181, 149, 105, 164, 170,
#         98, 101, 113, 134, 229, 115, 143,  95, 104, 123, 131, 108,  81,
#         99, 114, 129, 228, 128, 103, 107,  68, 138, 156, 167, 163, 186,
#        321, 135, 140, 180, 158, 210,  86, 162, 177, 204,  91, 172,  45,
#        145, 100, 196,  93, 120,  92, 144,  80, 183, 111, 141, 224, 171,
#        188,  94, 185,  85, 205, 212, 238,  72,  67,  76, 159,  83,  90,
#         84, 191, 197, 174,  97,  75, 157, 209,  82, 220,  64, 184, 168,
#        166, 192, 194, 193,  69,  70, 242,  79,  71,  78])

# %% [markdown]
# 3. Gross Column

# %%
# Checking unique Values
df['Gross'].unique()
# Out:
# array(['28,341,469', '134,966,411', '534,858,444', '57,300,000',
#        '4,360,000', '377,845,905', '107,928,762', '96,898,818',
#        '292,576,195', '37,030,102', '315,544,750', '330,252,182',
#        '6,100,000', '342,551,365', '171,479,930', '46,836,394',
#        '290,475,067', '112,000,000', nan, '53,367,844', '188,020,017',
#        '7,563,397', '10,055,859', '216,540,909', '136,801,374',
#        '57,598,247', '100,125,643', '130,742,922', '322,740,140',
#        '269,061', '335,451,311', '13,092,000', '13,182,281', '53,089,891',
#        '132,384,315', '32,572,577', '187,705,427', '6,719,864',
#        '23,341,568', '19,501,238', '422,783,777', '204,843,350',
#        '11,990,401', '210,609,762', '5,321,508', '32,000,000',
#        '1,024,560', '163,245', '19,181', '1,661,096', '5,017,246',
#        '12,391,761', '190,241,310', '858,373,000', '678,815,482',
#        '209,726,015', '162,805,434', '448,139,099', '6,532,908',
# ...

# %%
# Changing the 'Gross' Data by using the str.replace() function

# String replace() in Python returns a copy of the string where occurrences of a substring are replaced with another substring. 
df['Gross'] = df['Gross'].str.replace(',','')

# Conversion of data type from Object to Float by using astype() function
df['Gross'] = df['Gross'].astype(float)

# showing unique values
print(df['Gross'].unique())

# showing data type of the column
df['Gross'].dtype
# Out:
# [2.83414690e+07 1.34966411e+08 5.34858444e+08 5.73000000e+07
#  4.36000000e+06 3.77845905e+08 1.07928762e+08 9.68988180e+07
#  2.92576195e+08 3.70301020e+07 3.15544750e+08 3.30252182e+08
#  6.10000000e+06 3.42551365e+08 1.71479930e+08 4.68363940e+07
#  2.90475067e+08 1.12000000e+08            nan 5.33678440e+07
#  1.88020017e+08 7.56339700e+06 1.00558590e+07 2.16540909e+08
#  1.36801374e+08 5.75982470e+07 1.00125643e+08 1.30742922e+08
#  3.22740140e+08 2.69061000e+05 3.35451311e+08 1.30920000e+07
#  1.31822810e+07 5.30898910e+07 1.32384315e+08 3.25725770e+07
#  1.87705427e+08 6.71986400e+06 2.33415680e+07 1.95012380e+07
#  4.22783777e+08 2.04843350e+08 1.19904010e+07 2.10609762e+08
#  5.32150800e+06 3.20000000e+07 1.02456000e+06 1.63245000e+05
#  1.91810000e+04 1.66109600e+06 5.01724600e+06 1.23917610e+07
#  1.90241310e+08 8.58373000e+08 6.78815482e+08 2.09726015e+08
#  1.62805434e+08 4.48139099e+08 6.53290800e+06 1.22386900e+06
# ...

# %%
# checking null values
df['Gross'].isna().sum()
# Out:
# 169

# %% [markdown]
# There are 169 null values are present, which is much of 999 values so we will not drop these rows we will fill these values. For treating null values first we will check outliers.

# %%
# Checking Outliers
df['Gross'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Hence, Outliers found so we will fill these values with 0

# %% [markdown]
# Filing null values of the 'Gross' Column

# %%
# In this column we fill the Nan values with 0 by using numpy
df['Gross'] = df['Gross'].replace(np.nan,0)

# checking if there is any null values left in this Column
df['Gross'].isna().any()
# Out:
# False

# %% [markdown]
# 4. Meta_score

# %%
# showing unique values in 'Meta_score' Column
df['Meta_score'].unique()
# Out:
# array([ 80., 100.,  84.,  90.,  96.,  94.,  74.,  66.,  92.,  82.,  87.,
#         73.,  83.,  nan,  79.,  91.,  61.,  59.,  65.,  85.,  98.,  89.,
#         88.,  57.,  67.,  62.,  77.,  64.,  75.,  97.,  99.,  78.,  68.,
#         81.,  95.,  76.,  69.,  55.,  70.,  58.,  86.,  71.,  63.,  93.,
#         72.,  60.,  47.,  49.,  50.,  33.,  54.,  56.,  51.,  53.,  48.,
#         44.,  45.,  40.,  52.,  28.,  36.,  46.,  30.,  41.])

# %% [markdown]
# Since data has large number of null values so we will not drop it instead we will fill it but to fill these value we first have to check the presence of outliers. if there are outliers present in the data then will fill null values by median() else we will use mean() to fill null values.

# %%
# checking for outliers
df['Meta_score'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Filling null values in 'Meta_score' column

# %% [markdown]
# It is seen that there are lower bound outliers found so we fill null values with median.

# %%
# Finding median of 'Meta_score'
df['Meta_score'].median()
# Out:
# 79.0

# %%
# filling null values with median value of 'Meta_score'
df['Meta_score'].fillna(df['Meta_score'].median(),inplace=True)

# checking for null values
df['Meta_score'].isna().any()
# Out:
# False

# %%
# checking for unique values
df['Meta_score'].unique()
# Out:
# array([ 80., 100.,  84.,  90.,  96.,  94.,  74.,  66.,  92.,  82.,  87.,
#         73.,  83.,  79.,  91.,  61.,  59.,  65.,  85.,  98.,  89.,  88.,
#         57.,  67.,  62.,  77.,  64.,  75.,  97.,  99.,  78.,  68.,  81.,
#         95.,  76.,  69.,  55.,  70.,  58.,  86.,  71.,  63.,  93.,  72.,
#         60.,  47.,  49.,  50.,  33.,  54.,  56.,  51.,  53.,  48.,  44.,
#         45.,  40.,  52.,  28.,  36.,  46.,  30.,  41.])

# %% [markdown]
# 5. Certificate

# %%
# showing unique values
df['Certificate'].unique()
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', nan, 'PG', 'G', 'Passed', 'TV-14',
#        '16', 'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'],
#       dtype=object)

# %%
# counting values of the Certificate column
df['Certificate'].value_counts()
# Out:
# U           233
# A           197
# UA          175
# R           146
# PG-13        43
# PG           37
# Passed       34
# G            12
# Approved     11
# TV-PG         3
# GP            2
# TV-14         1
# 16            1
# TV-MA         1
# Unrated       1
# U/A           1
# Name: Certificate, dtype: int64

# %%
# Plotting count plot for 'Certificate' column
plt.figure(figsize=(10,5))
sns.countplot(y=df['Certificate'])
plt.show()

# %% [markdown]
# From this Plot we came to know that most of the movies having 'U' Certificate.

# %% [markdown]
# # Here I am going to give a bit information about the each certificates here.

# %% [markdown]
# 1. "U" = Universal. Used across several systems
# 2. "A" = In the Indian system, this is for 'Adults Only'
# 3. "UA" and "U/A" = Indian equivalent of UK PG. i.e. parental guidance recommended
# 4. "R" = Restricted. In the USA, under 17 requires accompanying parent or adult guardian
# 5. "PG-13" = Parents strongly cautioned – Some material may be inappropriate for children under 13
# 6. "PG" = Parental guidance suggested – Some material may not be suitable for children
# 7. "Passed" = Pre-dates cinema classification. There is no known rating, but was allowed to be released
# 8. "G" = General audiences – All ages admitted. Gonna fold into "U"
# 9."Approved" = Used interchangably with "Passed" as far as I can tell
# 10. "TV-PG" = Televsion movie rated PG. Fold into "PG"
# 11. "GP" = All ages admitted – Parental guidance suggested. Fold into "PG"
# 12. "TV-14" = Fold into "PG-13"
# 13. "16" = Irish classification. Fold into "R"
# 14. "TV-MA" = Fold into "R"
# 15. "Unrated" = Unrated. I am going to assume this is the same as the NaNs

# %%
# Let's bring some categories together by using .loc() method
df.loc[df['Certificate']=='U/A','Certificate'] = 'UA'
df.loc[df['Certificate']=='G','Certificate'] = 'U'
df.loc[df['Certificate']=='Approved', 'Certificate'] = 'Passed'
df.loc[df['Certificate']=='TV-PG', 'Certificate'] = 'PG'
df.loc[df['Certificate']=='GP', 'Certificate'] = 'PG'
df.loc[df['Certificate']=='TV-14', 'Certificate'] = 'PG-13'
df.loc[df['Certificate']=='16', 'Certificate'] = 'R'
df.loc[df['Certificate']=='TV-MA', 'Certificate'] = 'R'

# assuming missing certicate data means movies are unrated
# filling null values with Unrated one
df.loc[df['Certificate'].isna(), 'Certificate'] = 'Unrated'

# %%
# Counting values of Certificate Column
df['Certificate'].value_counts()
# Out:
# U          245
# A          197
# UA         176
# R          148
# Unrated    102
# Passed      45
# PG-13       44
# PG          42
# Name: Certificate, dtype: int64

# %%
# Plotting Percentage Distribution of movies on the basis of 'Certificate'
plt.figure(figsize=(12,10))
df['Certificate'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.title('Certificate Count Percentage Distribution')
plt.legend(df['Certificate'].value_counts().index)
plt.show()

# %% [markdown]
# In this plot,
# The most movies which are of certificate 'U' are rated in top 1000 of imdb because the U certificate movies are friendly to all categories of the people(adults,old,children) etc.

# %%
# checking null values
df.isnull().sum()  #Hence, 0 null values
# Out:
# Series_Title     0
# Released_Year    0
# Certificate      0
# Runtime          0
# Genre            0
# IMDB_Rating      0
# Meta_score       0
# Director         0
# Star1            0
# Star2            0
# Star3            0
# Star4            0
# No_of_Votes      0
# Gross            0
# dtype: int64

# %%
# Statistical Summary of Numerical Columns
df.describe()
# Out:
#        Released_Year     Runtime  IMDB_Rating  Meta_score   No_of_Votes  \
# count     999.000000  999.000000   999.000000  999.000000  9.990000e+02
# mean     1991.217217  122.873874     7.949650   78.134134  2.736974e+05
# std        23.297025   28.102520     0.275407   11.373863  3.275366e+05
# min      1920.000000   45.000000     7.600000   28.000000  2.508800e+04
# 25%      1976.000000  103.000000     7.700000   72.000000  5.547150e+04
# 50%      1999.000000  119.000000     7.900000   79.000000  1.383560e+05
# 75%      2009.000000  137.000000     8.100000   85.500000  3.744775e+05
# max      2020.000000  321.000000     9.300000  100.000000  2.343110e+06
#
#               Gross
# count  9.990000e+02
# mean   5.641946e+07
# std    1.032231e+08
# min    0.000000e+00
# 25%    4.422285e+05
# 50%    1.068028e+07
# 75%    6.139004e+07
# max    9.366622e+08

# %%
# Summary of Categorical Columns
df.describe(include='O')
# Out:
#        Series_Title Certificate  Genre          Director      Star1  \
# count           999         999    999               999        999
# unique          998           8    202               548        660
# top        Drishyam           U  Drama  Alfred Hitchcock  Tom Hanks
# freq              2         245     85                14         11
#
#               Star2         Star3          Star4
# count           999           999            999
# unique          840           891            938
# top     Emma Watson  Rupert Grint  Michael Caine
# freq              7             5              4

# %% [markdown]
# # Data Visuaization

# %%
# Plotting histogram for data
df.hist(figsize=(10,10),xrot=45)
plt.show()

# %% [markdown]
# Points from the above plotting
# 1. In "Released_Year" column position of releasing of  movies was increased year wise . Most of the movies from top 1000 IMBD Movies were released in the year between 2000 and 2020.
# 2. Most of the movies having their Runtime around 100 to 130 minutes.
# 3. The list of most of the movies from top 1000 IMBD Movies having range of Rating between 7.5 to 8.1.
# 4. Most of the movies having meta score of 80-85.
# 5. Most No. of Votes lies between 0.0 to 0.3 and gross lies between 0 to 1.

# %% [markdown]
# 1. Movies released Year wise

# %%
df['Released_Year'].value_counts()
# Out:
# 2014    32
# 2004    31
# 2009    29
# 2013    28
# 2016    28
#         ..
# 1930     1
# 1921     1
# 1936     1
# 1922     1
# 1943     1
# Name: Released_Year, Length: 99, dtype: int64

# %%
# Plotting Movies released in a year.
plt.figure(figsize=(20,5))
sns.countplot(x=df['Released_Year'])
plt.xticks(rotation = 90)
plt.xlabel('Years', fontsize= 10, fontweight = 'bold')
plt.title('Movies per Year', fontsize = 20)
plt.show()

# %% [markdown]
# From this plot it came to know that most of the movies were released in the year 2014.

# %% [markdown]
# 2. Distribution of Runtime

# %%
df['Runtime'].value_counts()
# Out:
# 100    23
# 130    23
# 129    22
# 101    22
# 113    22
#        ..
# 185     1
# 205     1
# 212     1
# 238     1
# 78      1
# Name: Runtime, Length: 140, dtype: int64

# %%
# Plotting Distribution of Runtime
df['Runtime'].plot(kind='kde', title='Distribution of Runtime')
plt.xlabel('Runtime in minutes')
plt.ylabel('Share of total')
plt.show()

# %% [markdown]
# This plot shows most of the movies from Top 1000 IMDB movies are having runtime around 100 to 130 minutes.

# %% [markdown]
# 3. Genre wise Distribution

# %%
df['Genre'].value_counts()
# Out:
# Drama                        85
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Adventure, Thriller           1
# Animation, Action, Sci-Fi     1
# Action, Crime, Comedy         1
# Animation, Crime, Mystery     1
# Adventure, Comedy, War        1
# Name: Genre, Length: 202, dtype: int64

# %%
# Plotting Genre wise Movies Distribution
plt.figure(figsize=(20,40))
df['Genre'].value_counts().plot(kind='barh', color='red')
plt.xlabel('No.of Series_Tiltle')
plt.ylabel('Genre')
plt.title('Genre Wise Distribution')
plt.show()

# %% [markdown]
# This plot implies that most of the movies are from 'Drama', 'Drama,Romance', 'Comedy, Drama' Genre.

# %% [markdown]
# 4. Rating wise Distribution

# %%
df['IMDB_Rating'].value_counts()
# Out:
# 7.7    157
# 7.8    151
# 8.0    141
# 8.1    127
# 7.6    122
# 7.9    106
# 8.2     67
# 8.3     44
# 8.4     31
# 8.5     20
# 8.6     15
# 8.7      5
# 8.8      5
# 8.9      3
# 9.0      3
# 9.2      1
# 9.3      1
# Name: IMDB_Rating, dtype: int64

# %%
# Plotting Rating wise Movies Distributon
df['IMDB_Rating'].plot(kind='hist', title='Rating Wise Distribution' , color='g')
plt.show()

# %% [markdown]
# This Plot shows most of the movies rating ranges between 7.7 to 8.

# %% [markdown]
# 5. Meta_score Wise Distribution

# %%
df['Meta_score'].value_counts()
# Out:
# 79.0    180
# 76.0     32
# 84.0     29
# 90.0     29
# 80.0     27
#        ...
# 28.0      1
# 36.0      1
# 46.0      1
# 30.0      1
# 41.0      1
# Name: Meta_score, Length: 63, dtype: int64

# %%
# Plotting Meta score wise Distribution
sns.displot(df['Meta_score'], color ='maroon', edgecolor='black')
plt.title('Meta_score Wise Distribution')
plt.xlabel('Meta_score')
plt.ylabel('No. of Series title')
plt.show()

# %% [markdown]
# This plot shows the highest Meta score which Top 1000 IMDB Movies are getting is 79 or 80.

# %% [markdown]
# 6. Finding Top 20 Directors

# %%
# Showing Top 20 Directors
df['Director'].value_counts().head(20).plot(kind='bar',title = 'Top 20 Directors', color='purple')
plt.xlabel('Director')
plt.ylabel('No. of Series Title')
plt.show()

# %% [markdown]
# This Plot shows most of the movies are directed by Alfred Hitchcock and then other directors come into list.

# %% [markdown]
# 7. Finding Top 10 Stars

# %%
star_list = df['Star1'].values.tolist() + df['Star2'].values.tolist() + df['Star3'].values.tolist() + df['Star4'].values.tolist()
pd.Series(star_list).value_counts().head(10)
# Out:
# Robert De Niro       17
# Al Pacino            13
# Tom Hanks            13
# Brad Pitt            12
# Clint Eastwood       12
# Christian Bale       11
# Leonardo DiCaprio    11
# Matt Damon           11
# James Stewart        10
# Johnny Depp           9
# dtype: int64

# %%
# Showing top 10 Actors
pd.Series(star_list).value_counts().head(10).plot(kind ='bar',color='hotpink', edgecolor='black')
plt.title('Top 10 Actors' , fontsize=20 , fontweight='bold')
plt.xlabel('Actors')
plt.ylabel('No. of Series Title')
plt.show()

# %% [markdown]
# 8. Showing Top 5 most Voted Movies

# %%
top_voted_movies = df.sort_values(by='No_of_Votes',ascending=False).head(5)
top_voted_movies
# Out:
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A      142
# 2           The Dark Knight           2008          UA      152
# 8                 Inception           2010          UA      148
# 9                Fight Club           1999           A      139
# 6              Pulp Fiction           1994           A      154
#
#                        Genre  IMDB_Rating  Meta_score           Director  \
# 0                      Drama          9.3        80.0     Frank Darabont
# 2       Action, Crime, Drama          9.0        84.0  Christopher Nolan
# 8  Action, Adventure, Sci-Fi          8.8        74.0  Christopher Nolan
# 9                      Drama          8.8        66.0      David Fincher
# 6               Crime, Drama          8.9        94.0  Quentin Tarantino
#
#                Star1                 Star2              Star3           Star4  \
# ...

# %%
plt.figure(figsize=(12,5))
sns.set_style('dark')
sns.set_palette('Set2')
sns.barplot(x= top_voted_movies['Series_Title'],y= top_voted_movies['No_of_Votes'])
plt.title('Top 5 most Voted Movies', fontweight='bold')
plt.xlabel('Movies', fontsize = 10, fontweight = 'bold')
plt.ylabel('Votes', fontsize = 10, fontweight = 'bold')
plt.show()

# %% [markdown]
# From this plot it came to know that top 5 most voted movies out of top 1000 imdb movies are The Shawshank Redemption, The Dark knight, Inception, fight club, Pulp Fiction.

# %% [markdown]
# 8.1. Showing Gross of Top 5 most voted movies

# %%
plt.figure(figsize=(12,5))
sns.set_style('dark')
sns.set_palette('Pastel1')
sns.barplot(x= top_voted_movies['Series_Title'],y= top_voted_movies['Gross'])
plt.title('Gross of Top 5 most Voted Movies', fontweight='bold', color='darkblue')
plt.xlabel('Movies')
plt.ylabel('Gross')
plt.show()

# %% [markdown]
# This plot shows that movies are not earning high even if they are getting highest votes.

# %% [markdown]
# 8.2. IMDB_Rating of Top 5 most voted movies

# %%
plt.figure(figsize=(12,5))
sns.set_style('dark')
sns.set_palette('Pastel2')
sns.barplot(x= top_voted_movies['Series_Title'],y= top_voted_movies['IMDB_Rating'])
plt.title('IMDB_Rating of Top 5 most Voted Movies', fontweight='bold')
plt.xlabel('Movies')
plt.ylabel('IMDB_Rating')
plt.show()

# %% [markdown]
# tHis plot shows a direct relation between Movies and IMDB_rating as the movie which is having good rating

# %% [markdown]
# 9. Showing 5 Movies with Highest Gross with their respective Released_years.

# %%
highest_gross_movies = df.sort_values(by='Gross',ascending=False).head(5)
highest_gross_movies
# Out:
#                                    Series_Title  Released_Year Certificate  \
# 477  Star Wars: Episode VII - The Force Awakens           2015           U
# 59                            Avengers: Endgame           2019          UA
# 623                                      Avatar           2009          UA
# 60                       Avengers: Infinity War           2018          UA
# 652                                     Titanic           1997          UA
#
#      Runtime                       Genre  IMDB_Rating  Meta_score  \
# 477      138   Action, Adventure, Sci-Fi          7.9        80.0
# 59       181    Action, Adventure, Drama          8.4        78.0
# 623      162  Action, Adventure, Fantasy          7.8        83.0
# 60       149   Action, Adventure, Sci-Fi          8.4        68.0
# 652      194              Drama, Romance          7.8        75.0
#
#           Director              Star1              Star2             Star3  \
# ...

# %%
plt.figure(figsize=(10,5))
sns.set_style('white')
sns.set_palette('Set3')
sns.barplot(x= highest_gross_movies['Series_Title'],y=highest_gross_movies['Gross'],hue=highest_gross_movies['Released_Year'])
plt.title('5 Highest Grossed Movies', fontsize=15)
plt.xticks(rotation=90)
plt.ylabel('Gross')
plt.xlabel('Movies')
plt.show()

# %% [markdown]
# From this Plot it came to know that 7 Most Grossed Movies from top 1000 IMDB Movie are Star Wars: Episode VII - The Force Awakensv, Avengers: Endgame, Avatar, Avengers: Infinity War,  Titanic, The Avengers, Incredibles 2.
#
# This Plot also shows the movie whose gross is highest was released in the year 2015.

# %% [markdown]
# 10. Showing 5 Highest Rated Movie

# %%
highest_rated_movies = df.sort_values(by='IMDB_Rating',ascending=False).head(5)
highest_rated_movies
# Out:
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A      142
# 1             The Godfather           1972           A      175
# 2           The Dark Knight           2008          UA      152
# 3    The Godfather: Part II           1974           A      202
# 4              12 Angry Men           1957           U       96
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1           Star2          Star3           Star4  No_of_Votes  \
# ...

# %%
sns.set_palette('Set1')
sns.scatterplot(x=highest_rated_movies['Series_Title'],y=highest_rated_movies['IMDB_Rating'],marker='^')
plt.title('5 Highest Rated Movie')
plt.xlabel('Movies')
plt.ylabel('IMDB_Rating')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The 5 Highest Rated Movies are : The Shawshank Redemption, The Godfather, The Dark Knight, The Godfather: Part II, 12 Angry Men

# %% [markdown]
# 11. Depict Relationship Between No. of Votes and Rating based on certificate.

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x='No_of_Votes',y='IMDB_Rating',hue='Certificate',style='Certificate')
plt.show()

# %% [markdown]
# 12. Depict Relationship Between Gross and Rating based on Certificate.

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x='Gross',y='IMDB_Rating',hue='Certificate',style='Certificate')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# 13. Depict Relationship Between Meta_score and Rating based on Certificate

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x='Meta_score',y='IMDB_Rating',hue='Certificate',style='Certificate')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# 14. Depict Relationship Between Released Year and Rating Based on Certificate

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x='Released_Year',y='IMDB_Rating',hue='Certificate',style='Certificate')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Group by Operation Based EDA

# %% [markdown]
# 1. Plot a barplot for top 5 gross directors.

# %%
#Create a dataset of groupby total gross per director.

top_gross_dir = df.groupby(['Director'])['Gross'].sum().sort_values(ascending=False).head(5)
top_gross_dir
# Out:
# Director
# Steven Spielberg     2.478133e+09
# Anthony Russo        2.205039e+09
# Christopher Nolan    1.937454e+09
# James Cameron        1.748237e+09
# Peter Jackson        1.597312e+09
# Name: Gross, dtype: float64

# %%
top_gross_dir.plot(kind='bar')
plt.title('Top 5 Gross Directors')
plt.xlabel('Director')
plt.ylabel('Gross')
plt.show()

# %% [markdown]
# The Top 5 Gross Directors are: Steven Spielberg, Anthony Russo, Christopher Nolan, James Cameron, Peter Jackson

# %% [markdown]
# 2. Plot a barplot for Top 5 Gross Stars.

# %%
top_gross_stars = df.groupby([pd.Series(star_list)])[['Gross']].sum().sort_values(by='Gross',ascending=False).head(5)
top_gross_stars
# Out:
#                           Gross
# Tom Hanks          2.319260e+09
# Joe Russo          2.205039e+09
# Leonardo DiCaprio  1.877322e+09
# Daniel Radcliffe   1.835901e+09
# Christian Bale     1.351591e+09

# %%
top_gross_stars.plot(kind='bar')
plt.title('Top 5 Gross Stars')
plt.xlabel('Stars')
plt.ylabel('Gross')
plt.show()

# %% [markdown]
# The Top 5 Gross Stars are: Tom Hanks, Joe Russo, Leonardo DiCaprio, Daniel Radcliffe, Christian Bale.

# %% [markdown]
# top 7 Gross Genres

# %%
top_gross_genre = df.groupby(['Genre'])[['Gross']].sum().sort_values(by='Gross',ascending=False).head(7)
top_gross_genre
# Out:
#                                      Gross
# Genre
# Action, Adventure, Sci-Fi     5.898659e+09
# Animation, Adventure, Comedy  4.503338e+09
# Action, Adventure, Drama      2.668836e+09
# Action, Adventure, Fantasy    2.116341e+09
# Drama                         2.020898e+09
# Animation, Action, Adventure  2.008695e+09
# Drama, Romance                1.962892e+09

# %%
top_gross_genre.plot(kind='barh')
plt.title('Top 7 Gross Genre')
plt.xlabel('Gross')
plt.show()

# %% [markdown]
# The Top 7 Gross Genres are:
# 1. Action, Adventure, Sci-Fi
# 2. Animation, Adventure, Comedy
# 3. Action, Adventure, Drama
# 4. Action, Adventure, Fantasy
# 5. Drama
# 6. Animation, Action, Adventure
# 7. Drama, Romance

# %% [markdown]
# The Top 10 Gross Years

# %%
gross_years = df.groupby(['Released_Year'])[['Gross']].sum().sort_values(by='Gross',ascending=False).head(10)
gross_years
# Out:
#                       Gross
# Released_Year
# 2009           2.937171e+09
# 2014           2.755629e+09
# 2018           2.607757e+09
# 2016           2.595557e+09
# 2012           2.542616e+09
# 2010           2.490222e+09
# 2015           2.462337e+09
# 2019           2.406743e+09
# 2001           2.097819e+09
# 2017           2.061313e+09

# %%
gross_years.plot(kind='bar',title='Top 10 Gross Years')
plt.xticks(rotation=45)
plt.ylabel('Gross')
plt.show()

# %% [markdown]
# The Top 10 Gross years are: 2009, 2014, 2018, 2016, 2012, 2010, 2015, 2019, 2001, 2017

# %%
# Plotting correlation matrix for numerical columns
sns.heatmap(df.corr(), cmap='coolwarm',annot=True)
plt.show()

# %% [markdown]
# This heatmap shows the following correlations -
# 1. No_of_Votes and Gross: Makes sense. If more people have paid to see the film, more people are going to vote for the movie on IMDB.
# 2. No_of_Votes and IMDB_rating: I suppose people are more likely to rate a film they like.
# 3. Meta_score and Released_Year: An interesting slight negative correlation. Older films tend to have higher ratings.
# 4. IMDB_Rating and Meta_score: Not very correlated, which is interesting, where one might imagine the scores would track well but still ratings are same.

# %%
# Plotting Pair plot for data
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Gathering insights from The Data

# %% [markdown]
# 1. Top 10 Combination of Actors are getting good gross together

# %%
avg_gross=df['Gross'].mean()
print(avg_gross)
df1 =df[df['Gross']>avg_gross].groupby(['Star1','Star2'])[['Gross']].sum().sort_values(by='Gross',ascending=False).reset_index().head(10)
df1
# Out:
# 56419459.5025025
#                Star1              Star2         Gross
# 0          Joe Russo  Robert Downey Jr.  1.537188e+09
# 1   Daniel Radcliffe        Emma Watson  1.518325e+09
# 2          Tom Hanks          Tim Allen  1.040839e+09
# 3       Daisy Ridley        John Boyega  9.366622e+08
# 4        Mark Hamill      Harrison Ford  9.223406e+08
# 5    Sam Worthington        Zoe Saldana  7.605076e+08
# 6          Joe Russo        Chris Evans  6.678509e+08
# 7  Leonardo DiCaprio       Kate Winslet  6.593254e+08
# 8        Elijah Wood       Ian McKellen  6.580961e+08
# 9  Robert Downey Jr.        Chris Evans  6.232795e+08

# %% [markdown]
# 2. The Most no. of movies are released in the year 2014 so, Let's Find what are the movies that are released in the year 2014.

# %%
df.head(2)
# Out:
#                Series_Title  Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption           1994           A      142         Drama
# 1             The Godfather           1972           A      175  Crime, Drama
#
#    IMDB_Rating  Meta_score              Director          Star1  \
# 0          9.3        80.0        Frank Darabont    Tim Robbins
# 1          9.2       100.0  Francis Ford Coppola  Marlon Brando
#
#             Star2       Star3           Star4  No_of_Votes        Gross
# 0  Morgan Freeman  Bob Gunton  William Sadler      2343110   28341469.0
# 1       Al Pacino  James Caan    Diane Keaton      1620367  134966411.0

# %%
# Movies Released in the Year 2014
df2 = df[df['Released_Year']==2014]
df2['Series_Title']
# Out:
# 21                                        Interstellar
# 34                                            Whiplash
# 200                                              Mommy
# 201                                             Haider
# 204                                   Relatos salvajes
# 206                                         Kis Uykusu
# 207                                                 PK
# 209                           The Grand Budapest Hotel
# 210                                          Gone Girl
# 219                                    Song of the Sea
# 337                           Serbuan maut 2: Berandal
# 338                                 The Imitation Game
# 339                            Guardians of the Galaxy
# 372                                        Mar adentro
# 474                                       Nightcrawler
# 479                         X-Men: Days of Future Past
# 482                                   Edge of Tomorrow
# ...

# %% [markdown]
# 3. Most of the movies have U Certificate , Let's Find the name of 30 Movies having U Certificate.

# %%
# 30 Movies having U Certificate
df3 = df[df['Certificate']=='U']
df3['Series_Title'].sample(30)
# Out:
# 632             The World's Fastest Indian
# 238                    Munna Bhai M.B.B.S.
# 971                      Omohide poro poro
# 532                     The Blues Brothers
# 378                        The Incredibles
# 828                Who Framed Roger Rabbit
# 969                     Dazed and Confused
# 824                         A Few Good Men
# 95                                  Amélie
# 996                                  Giant
# 576                           Paddington 2
# 594                       English Vinglish
# 260                  Trois couleurs: Rouge
# 820                              Malcolm X
# 367                            Ratatouille
# 679               Ferris Bueller's Day Off
# 374                          Kal Ho Naa Ho
# 698    Willy Wonka & the Chocolate Factory
# 50                              Casablanca
# 671                             Awakenings
# 735                            Kai po che!
# 99                       Good Will Hunting
# ...

# %% [markdown]
# 4. Most of the movies from Top 1000 IMDB Movies are from 'Drama' Genre. So, let's find 20 movies along with their stars.

# %%
# 20 Movies from 'Drama' Genre along with Stars
df4 = df[df['Genre']=='Drama']
df4[['Star1','Star2','Star3','Star4','Series_Title']].sample(20)
# Out:
#                       Star1                 Star2               Star3  \
# 916         Richard Jenkins          Haaz Sleiman        Danai Gurira
# 89             Payman Maadi          Leila Hatami         Sareh Bayat
# 0               Tim Robbins        Morgan Freeman          Bob Gunton
# 423  Jean-Louis Trintignant    Stefania Sandrelli     Gastone Moschin
# 765          Mads Mikkelsen  Sidse Babett Knudsen       Rolf Lassgård
# 121         Takashi Shimura          Nobuo Kaneko    Shin'ichi Himori
# 274             Bertil Guve       Pernilla Allwin  Kristina Adolphson
# 141          Rajat Barmecha             Ronit Roy        Manjot Singh
# 432    Marcello Mastroianni           Anouk Aimée   Claudia Cardinale
# 391      Billy Bob Thornton         Dwight Yoakam          J.T. Walsh
# 981       Katharine Hepburn           Henry Fonda          Jane Fonda
# 439        Elizabeth Taylor           Paul Newman           Burl Ives
# ...

# %% [markdown]
# 5. 10 Movies with Highest Rating having gross is less than avg_gross'

# %%
df5 = df[df['Gross']<avg_gross]
df5[['Series_Title','IMDB_Rating','Gross']].sort_values(by='IMDB_Rating',ascending=False).head(10)
# Out:
#                        Series_Title  IMDB_Rating       Gross
# 0          The Shawshank Redemption          9.3  28341469.0
# 4                      12 Angry Men          9.0   4360000.0
# 9                        Fight Club          8.8  37030102.0
# 12  Il buono, il brutto, il cattivo          8.8   6100000.0
# 15                       Goodfellas          8.7  46836394.0
# 23    Sen to Chihiro no kamikakushi          8.6  10055859.0
# 32            It's a Wonderful Life          8.6         0.0
# 31             Shichinin no samurai          8.6    269061.0
# 30                          Seppuku          8.6         0.0
# 22                   Cidade de Deus          8.6   7563397.0

# %% [markdown]
# This shows Even if the Rating is High but still movies are not earning in a good amount. Like '12 Angry Man ', 'Seppuku' are some of the movies which are true example of this situation.

# %% [markdown]
# # Conclusion

# %% [markdown]
# This Dataset contains Top 1000 Imdb Movies.
# 1. In 2014 Movies released ona very high scale.
# 2. Steven Spielberg is the Director comes on 1st Position in terms of earning.
# 3. Tom Hanks is one of the Star who is on 1st Position in terms of Gross.
# 4. Released movies in the year 2009 having the Highest Gross.
# 5. Rating and Gross are not very correlated to each other.
# 6. 'Drama' Genre contains the most no. of movies but in terms of grossing 'Action, Adventure, Scifi' Genre tops in the list.
